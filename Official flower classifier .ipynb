# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
import matplotlib.pyplot as plt

#plot on the x and y the columns I want
x_index = 0
y_index = 1

#color bar legend
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])

plt.figure(figsize=(5, 4))
plt.scatter(iris.data[:, x_index], iris.data[:, y_index], c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index])

plt.tight_layout()
plt.show()

# %%
X = iris.data
y = iris.target

feature_names = iris.feature_names
target_names = iris.target_names

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape)
print(X_test.shape)
# Out:
# (120, 4)
# (30, 4)

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
knn_y_pred = knn.predict(X_test) 

from sklearn import metrics
print(metrics.accuracy_score(y_test, knn_y_pred))
# Out:
# 0.9666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier 
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)

# %%
dtc_y_pred = dtc.predict(X_test) 

from sklearn import metrics
print(metrics.accuracy_score(y_test, dtc_y_pred))

# %%
sample = [[3,5,4,2], [2,3,5,4]]
predictions = knn.predict(sample)
pred_species = [iris.target_names[p] for p in predictions]
print('predictions: ', pred_species)
# Out:
# predictions:  ['versicolor', 'virginica']

# %%
from joblib import dump, load
dump(knn, 'mlbrain2.joblib') #this stores the pre-trained file ready to be called on
# Out:
# ['mlbrain2.joblib']

# %%
model = load('mlbrain2.joblib') #now I can call my already trained model and have it predict using new data that I am giving it
sample = [[2,3.4,5,2.5], [1,2,3,2]]
predictions = knn.predict(sample)
pred_species = [iris.target_names[p] for p in predictions]
print('predictions: ', pred_species)
# Out:
# predictions:  ['versicolor', 'setosa']
